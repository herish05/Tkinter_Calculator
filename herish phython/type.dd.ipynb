# %%
a="name"
print(type(a))
a=10
print(type(a))
a=-112.12
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
a=100
print(id(a))
a=100
print(id(a))
# Out:
# 140719100174216
# 140719100174216

# %%
a=10
id1=id(a)
b=a+2-2
id2=id(a)
print(id1)
print(id2)
# Out:
# 140719100171336
# 140719100171336

# %%
a=input()
b=input()
c=a+b
print(c)
# Out:
# 40
# 57
# 4057

# %%
a=int(input())
b=int(input())
c=a+b
print(c)
# Out:
# abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a=int(input())
#       2 b=int(input())
#       3 c=a+b
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
test1=int(input( "marks1"))
test2=int(input(" marks2"))
test3=int(input( "marks3"))
print((test1+test2+test3)/3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 test1=int(input( "marks1"))
#       2 test2=int(input(" marks2"))
#       3 test3=int(input( "marks3"))
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
# ...

# %%
N=int(input())
firsthalf=(N+1)//2
secondhalf=N//2
i=1
while i<=firsthalf:
    spaces=1
    while spaces<=(firsthalf-i):
        print(end="")
        spaces+=1
    j=1
    while j<=(2*i-1):
        print('*',end="")
        j+=1
    print()
    i+=1
i=secondhalf    
while  i>=1:
    spaces+=1
    while(spaces<=(secondhalf-i+1)):
        print(end="")
        spaces+=1
    j=1
    while j<=(2*i-1):
        print('*',end="")
        j+=1
    print()
    i-=1
# Out:
# 5
# *
# ***
# *****
# ***
# *

# %%
n=int(input())
i=1
while i<=n:
    j=1
    k=1
    while j<=i:
        print(k,end="")
        j=j+1
        k=k+1
    print()
    i=i+1
while i<=n:
    spaces=1
    while spaces<n-i+1:
        print('',end="")
        spaces+=1
    
while i<=n:
    spaces=1
    while spaces<=n-i:
        print(' ',end="")
        spaces=spaces+1
    stars=1
    k=1
    while stars<=i:
        print(k,end="")
        stars=stars+1
        k=k+1
    print()
    i=i+1
# Out:
# 5
# 1
# 12
# 123
# 1234
# 12345
